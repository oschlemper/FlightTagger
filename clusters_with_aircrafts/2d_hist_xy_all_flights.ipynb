# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %%
clusters = pd.read_hdf('clusters_with_aircrafts_all_months.h5')
clusters.drop_duplicates(inplace=True, ignore_index=True)
clusters = clusters[clusters.cluster_time != 0]
clusters['running_cluster_index'] = np.cumsum(np.abs(clusters.time_cluster.diff())>0)

# %%
clusters.head(15)
# Out:
#     station_number  run_number  event_number  readout_time  \
# 0               22          86             1  1.627085e+09
# 1               22          86             2  1.627085e+09
# 2               22          86             0  1.627085e+09
# 3               22          87             1  1.627092e+09
# 4               22          87             0  1.627092e+09
# 5               22          87             2  1.627092e+09
# 6               22          90             0  1.627114e+09
# 7               22          90             1  1.627114e+09
# 8               22          90             2  1.627114e+09
# 9               22          91             0  1.627121e+09
# 10              22          91             1  1.627121e+09
# 11              22          91             2  1.627121e+09
# 12              22          99             0  1.627417e+09
# 13              22          99             1  1.627417e+09
# 14              22          99             2  1.627417e+09
#
#     read_trigger_difference  trigger_time  mattak_trigger_time  force_trigger  \
# 0                 -0.460160  1.627085e+09         1.627085e+09          False
# 1                 -0.001984  1.627085e+09         1.627085e+09          False
# 2                 -0.488737  1.627085e+09         1.627085e+09          False
# 3                 -0.298171  1.627092e+09         1.627092e+09          False
# 4                 -0.324630  1.627092e+09         1.627092e+09          False
# 5                  0.000314  1.627092e+09         1.627092e+09          False
# 6                 -0.172738  1.627114e+09         1.627114e+09          False
# 7                 -0.143147  1.627114e+09         1.627114e+09          False
# 8                  0.000865  1.627114e+09         1.627114e+09          False
# 9                 -0.040267  1.627121e+09         1.627121e+09          False
# 10                -0.011934  1.627121e+09         1.627121e+09          False
# 11                 0.014849  1.627121e+09         1.627121e+09          False
# 12                -0.488740  1.627417e+09         1.627417e+09          False
# 13                -0.460278  1.627417e+09         1.627417e+09          False
# 14                 0.001206  1.627417e+09         1.627417e+09          False
#
#     radiant_trigger  lt_trigger  pps_num     sysclk  sysclk_last_pps  \
# 0             False       False        3  300000264        300000262
# 1             False       False        5  500000462        500000460
# 2             False       False        2  200000157        200000155
# 3             False       False        5  500000260        500000258
# 4             False       False        4  400000213        400000211
# 5             False       False        6  600000288        600000286
# 6             False       False        2  200000030        200000028
# 7             False       False        3  300000036        300000034
# 8             False       False        4  400000054        400000052
# 9             False       False        3  300000231        300000229
# 10            False       False        4  400000312        400000310
# 11            False       False        5  500000401        500000399
# 12            False       False        2  200000171        200000169
# 13            False       False        3  300000257        300000255
# 14            False       False        5  500000433        500000431
#
#     sysclk_last_last_pps  station  sysclks_ok       run_type  \
# 0              200000155       22        True  not specified
# 1              400000358       22        True  not specified
# 2              100000075       22        True  not specified
# 3              400000211       22        True  not specified
# 4              300000158       22        True  not specified
# 5              500000258       22        True  not specified
# 6              100000003       22        True  not specified
# 7              200000028       22        True  not specified
# 8              300000034       22        True  not specified
# 9              200000153       22        True  not specified
# 10             300000229       22        True  not specified
# 11             400000310       22        True  not specified
# 12             100000079       22        True  not specified
# 13             200000169       22        True  not specified
# 14             400000337       22        True  not specified
#
#     time_since_first  time_cluster  time_cluster_size   x   y   z     hexcode  \
# 0       6.895830e+05       1851674                  3 NaN NaN NaN  NONE_FOUND
# 1       6.895830e+05       1851674                  3 NaN NaN NaN  NONE_FOUND
# 2       6.895830e+05       1851674                  3 NaN NaN NaN  NONE_FOUND
# 3       6.967900e+05       1861574                  3 NaN NaN NaN  NONE_FOUND
# 4       6.967900e+05       1861574                  3 NaN NaN NaN  NONE_FOUND
# 5       6.967900e+05       1861574                  3 NaN NaN NaN  NONE_FOUND
# 6       7.184100e+05       1891284                  3 NaN NaN NaN  NONE_FOUND
# 7       7.184100e+05       1891284                  3 NaN NaN NaN  NONE_FOUND
# 8       7.184100e+05       1891284                  3 NaN NaN NaN  NONE_FOUND
# 9       7.256160e+05       1901857                  3 NaN NaN NaN  NONE_FOUND
# 10      7.256160e+05       1901857                  3 NaN NaN NaN  NONE_FOUND
# 11      7.256160e+05       1901857                  3 NaN NaN NaN  NONE_FOUND
# 12      1.021898e+06       2013955                  3 NaN NaN NaN  NONE_FOUND
# 13      1.021898e+06       2013955                  3 NaN NaN NaN  NONE_FOUND
# 14      1.021898e+06       2013955                  3 NaN NaN NaN  NONE_FOUND
#
#    flightnumber  rssi  cluster_time  running_cluster_index
# 0    NONE_FOUND   NaN  1.627085e+09                      0
# 1    NONE_FOUND   NaN  1.627085e+09                      0
# 2    NONE_FOUND   NaN  1.627085e+09                      0
# 3    NONE_FOUND   NaN  1.627092e+09                      1
# 4    NONE_FOUND   NaN  1.627092e+09                      1
# 5    NONE_FOUND   NaN  1.627092e+09                      1
# 6    NONE_FOUND   NaN  1.627114e+09                      2
# 7    NONE_FOUND   NaN  1.627114e+09                      2
# 8    NONE_FOUND   NaN  1.627114e+09                      2
# 9    NONE_FOUND   NaN  1.627121e+09                      3
# 10   NONE_FOUND   NaN  1.627121e+09                      3
# 11   NONE_FOUND   NaN  1.627121e+09                      3
# 12   NONE_FOUND   NaN  1.627417e+09                      4
# 13   NONE_FOUND   NaN  1.627417e+09                      4
# 14   NONE_FOUND   NaN  1.627417e+09                      4

# %%
np.max(clusters.time_cluster_size.unique()) # cant trust time_cluster_size, h5 file contains duplicate values
# Out:
# np.int64(37)

# %%
unique_clusters = clusters.running_cluster_index.unique()
cluster_size_check = []
for cluster_index in unique_clusters:
    tmp = clusters[clusters.running_cluster_index == cluster_index] # get rows that belong to current cluster
    size = len(tmp) # get cluster size
    num_stations = len(tmp.station.unique()) # get number of stations in cluster (should match cluster size in best case)
    cluster_size_check.append([size, num_stations])
cluster_size_check = np.array(cluster_size_check)

# %%
edges = range(8)
plt.hist2d(cluster_size_check[:, 0], cluster_size_check[:, 1], bins = [edges, edges])
plt.xlabel('cluster_size')
plt.ylabel('num_stations')
plt.show()

# %%
len(clusters)
# Out:
# 89366

# %%
len(clusters[~clusters.rssi.isna()])
# Out:
# 86979

# %%
clusters_of_interest = clusters[~(clusters.rssi.isna() | clusters.x.isna() | clusters.y.isna())][['station_number', 'rssi', 'x', 'y']]

# %%
clusters_of_interest['x'] = clusters_of_interest.x / 1000
clusters_of_interest['y'] = clusters_of_interest.y / 1000
data = clusters_of_interest

# %%
bin_size = 5 # km

data['x_bin'] = ((data['x']) // bin_size).astype(int) * bin_size
data['y_bin'] = ((data['y']) // bin_size).astype(int) * bin_size

averaged_data = data.groupby(['x_bin', 'y_bin'])['rssi'].mean().reset_index()

pivot_table = averaged_data.pivot(index='y_bin', columns='x_bin', values='rssi')

x_edges = np.arange(data['x'].min(), data['x'].max() + bin_size, bin_size).astype(int)
y_edges = np.arange(data['y'].min(), data['y'].max() + bin_size, bin_size).astype(int)

sns.heatmap(pivot_table, cmap='viridis', cbar_kws={'label': 'avg rssi [dB]'})
plt.xlabel('x [km]')
plt.ylabel('y [km]')
plt.show()

# %%
data = clusters_of_interest
data['r2d'] = np.sqrt(data.x**2 + data.y**2)
#data['r3d'] = np.sqrt(data.x**2 + data.y**2 + data.z**2)
data['r2d_bin'] = ((data['r2d']) // bin_size).astype(int) * bin_size
averaged_data = data.groupby(['r2d_bin'])['rssi'].mean().reset_index()
plt.plot(averaged_data.r2d_bin, averaged_data.rssi, '.-')
plt.xlabel('r (2D) [km]')
plt.ylabel('avg rssi [dB]')
plt.show()

# %%
averaged_data
# Out:
#     r2d_bin       rssi
# 0         0  -4.911701
# 1         5  -7.110439
# 2        10  -8.710126
# 3        15 -13.668577
# 4        20 -12.503872
# ..      ...        ...
# 59      295 -31.080005
# 60      300 -30.835540
# 61      305 -32.278196
# 62      310 -33.417771
# 63      315 -30.360513
#
# [64 rows x 2 columns]
